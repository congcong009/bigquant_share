# %%
# 本代码由可视化策略环境自动生成 2021年8月22日09:56
# 本代码单元只能在可视化模式下编辑。您也可以拷贝代码，粘贴到新建的代码单元或者策略，然后修改。


# Python 代码入口函数，input_1/2/3 对应三个输入端，data_1/2/3 对应三个输出端
def m15_run_bigquant_run(input_1, input_2, input_3):
    # 示例代码如下。在这里编写您的代码
    df = input_1.read_df()
    df['date0'] = df['date'].apply(lambda x: x[0:11] + ' 00:00:00')
    df['date1'] = df['date0'].apply(lambda x: datetime.datetime.strptime(x, '%Y-%m-%d %H:%M:%S'))
    df = df.drop(['date','date0'], axis=1)
    df = df.rename(columns={'date1': 'date'})
    #df = pd.DataFrame({'data': [1, 2, 3]})
    data_1 = DataSource.write_df(df)
    data_2 = DataSource.write_pickle(df)
    return Outputs(data_1=data_1, data_2=None, data_3=None)

# 后处理函数，可选。输入是主函数的输出，可以在这里对数据做处理，或者返回更友好的outputs数据格式。此函数输出不会被缓存。
def m15_post_run_bigquant_run(outputs):
    return outputs

# Python 代码入口函数，input_1/2/3 对应三个输入端，data_1/2/3 对应三个输出端
def m7_run_bigquant_run(input_1, input_2, input_3):
    # 示例代码如下。在这里编写您的代码
    #df = pd.DataFrame({'data': [1, 2, 3]})
    df = input_1.read_df()
    df1 = df[df!= 0]
    data_1 = DataSource.write_df(df1)
    #data_2 = DataSource.write_pickle(df)
    return Outputs(data_1=data_1, data_2=None, data_3=None)

# 后处理函数，可选。输入是主函数的输出，可以在这里对数据做处理，或者返回更友好的outputs数据格式。此函数输出不会被缓存。
def m7_post_run_bigquant_run(outputs):
    return outputs

# Python 代码入口函数，input_1/2/3 对应三个输入端，data_1/2/3 对应三个输出端
def m17_run_bigquant_run(input_1, input_2, input_3):
    # 示例代码如下。在这里编写您的代码
    #df = pd.DataFrame({'data': [1, 2, 3]})
    df = input_1.read_df()
    df1 = df[df.columns.difference(['date'])]
    df2 = df1.applymap(lambda x: np.log(x))
    df2['date'] = df['date']
    data_1 = DataSource.write_df(df2)
    #data_2 = DataSource.write_pickle(df)
    return Outputs(data_1=data_1, data_2=None, data_3=None)

# 后处理函数，可选。输入是主函数的输出，可以在这里对数据做处理，或者返回更友好的outputs数据格式。此函数输出不会被缓存。
def m17_post_run_bigquant_run(outputs):
    return outputs

# Python 代码入口函数，input_1/2/3 对应三个输入端，data_1/2/3 对应三个输出端
def m21_run_bigquant_run(input_1, input_2, input_3):
    # 示例代码如下。在这里编写您的代码
    #df = pd.DataFrame({'data': [1, 2, 3]})
    df = input_1.read_df()
    df['instrument'] = 'BTC_USDT.HBI'
    data_1 = DataSource.write_df(df)
    #data_2 = DataSource.write_pickle(df)
    return Outputs(data_1=data_1, data_2=None, data_3=None)

# 后处理函数，可选。输入是主函数的输出，可以在这里对数据做处理，或者返回更友好的outputs数据格式。此函数输出不会被缓存。
def m21_post_run_bigquant_run(outputs):
    return outputs

# Python 代码入口函数，input_1/2/3 对应三个输入端，data_1/2/3 对应三个输出端
def m4_run_bigquant_run(input_1, input_2, input_3):
    # 示例代码如下。在这里编写您的代码
    df = input_1.read_df()
    df['date0'] = df['date'].apply(lambda x: x[0:11] + ' 00:00:00')
    df['date1'] = df['date0'].apply(lambda x: datetime.datetime.strptime(x, '%Y-%m-%d %H:%M:%S'))
    df = df.drop(['date','date0'], axis=1)
    df = df.rename(columns={'date1': 'date'})
    #df = pd.DataFrame({'data': [1, 2, 3]})
    data_1 = DataSource.write_df(df)
    data_2 = DataSource.write_pickle(df)
    return Outputs(data_1=data_1, data_2=None, data_3=None)

# 后处理函数，可选。输入是主函数的输出，可以在这里对数据做处理，或者返回更友好的outputs数据格式。此函数输出不会被缓存。
def m4_post_run_bigquant_run(outputs):
    return outputs

# Python 代码入口函数，input_1/2/3 对应三个输入端，data_1/2/3 对应三个输出端
def m25_run_bigquant_run(input_1, input_2, input_3):
    # 示例代码如下。在这里编写您的代码
    #df = pd.DataFrame({'data': [1, 2, 3]})
    df = input_1.read_df()
    df1 = df[df.columns.difference(['date'])]
    df2 = df1.apply(lambda col: np.cumsum(col))
    df2['date'] = df['date']
    data_1 = DataSource.write_df(df2)
    #data_2 = DataSource.write_pickle(df)
    return Outputs(data_1=data_1, data_2=None, data_3=None)

# 后处理函数，可选。输入是主函数的输出，可以在这里对数据做处理，或者返回更友好的outputs数据格式。此函数输出不会被缓存。
def m25_post_run_bigquant_run(outputs):
    return outputs

# Python 代码入口函数，input_1/2/3 对应三个输入端，data_1/2/3 对应三个输出端
def m5_run_bigquant_run(input_1, input_2, input_3):
    # 示例代码如下。在这里编写您的代码
    #df = pd.DataFrame({'data': [1, 2, 3]})
    df = input_1.read_df()
    df1 = df[df!= 0]
    data_1 = DataSource.write_df(df1)
    #data_2 = DataSource.write_pickle(df)
    return Outputs(data_1=data_1, data_2=None, data_3=None)

# 后处理函数，可选。输入是主函数的输出，可以在这里对数据做处理，或者返回更友好的outputs数据格式。此函数输出不会被缓存。
def m5_post_run_bigquant_run(outputs):
    return outputs

# Python 代码入口函数，input_1/2/3 对应三个输入端，data_1/2/3 对应三个输出端
def m22_run_bigquant_run(input_1, input_2, input_3):
    # 示例代码如下。在这里编写您的代码
    #df = pd.DataFrame({'data': [1, 2, 3]})
    df = input_1.read_df()
    df1 = df[df.columns.difference(['date'])]
    df2 = df1.applymap(lambda x: np.log(x))
    df2['date'] = df['date']
    data_1 = DataSource.write_df(df2)
    #data_2 = DataSource.write_pickle(df)
    return Outputs(data_1=data_1, data_2=None, data_3=None)

# 后处理函数，可选。输入是主函数的输出，可以在这里对数据做处理，或者返回更友好的outputs数据格式。此函数输出不会被缓存。
def m22_post_run_bigquant_run(outputs):
    return outputs

# Python 代码入口函数，input_1/2/3 对应三个输入端，data_1/2/3 对应三个输出端
def m27_run_bigquant_run(input_1, input_2, input_3):
    # 示例代码如下。在这里编写您的代码
    #df = pd.DataFrame({'data': [1, 2, 3]})
    df = input_1.read()
    df['residual'] = df['label'] - df['pred_label']
    data_1 = DataSource.write_df(df)
    #data_2 = DataSource.write_pickle(df)
    return Outputs(data_1=data_1, data_2=None, data_3=None)

# 后处理函数，可选。输入是主函数的输出，可以在这里对数据做处理，或者返回更友好的outputs数据格式。此函数输出不会被缓存。
def m27_post_run_bigquant_run(outputs):
    return outputs

# Python 代码入口函数，input_1/2/3 对应三个输入端，data_1/2/3 对应三个输出端
def m23_run_bigquant_run(input_1, input_2, input_3, string, start_date, end_date, market):
    # 示例代码如下。在这里编写您的代码
    #df = pd.DataFrame({'data': [1, 2, 3]})
    list_1 = []
    list_1.append(string)
    dict_1 = {'instruments': list_1, 'start_date': start_date, 'end_date': end_date, 'market': market}
    #data_1 = DataSource.write_df(df)
    data_1 = DataSource.write_pickle(dict_1)
    return Outputs(data_1=data_1, data_2=None, data_3=None)

# 后处理函数，可选。输入是主函数的输出，可以在这里对数据做处理，或者返回更友好的outputs数据格式。此函数输出不会被缓存。
def m23_post_run_bigquant_run(outputs):
    return outputs

# Python 代码入口函数，input_1/2/3 对应三个输入端，data_1/2/3 对应三个输出端
def m42_run_bigquant_run(input_1, input_2, input_3):
    # 示例代码如下。在这里编写您的代码
    #df = pd.DataFrame({'data': [1, 2, 3]})
    df = input_1.read_df()
    df1 = df[df!= 0]
    data_1 = DataSource.write_df(df1)
    #data_2 = DataSource.write_pickle(df)
    return Outputs(data_1=data_1, data_2=None, data_3=None)

# 后处理函数，可选。输入是主函数的输出，可以在这里对数据做处理，或者返回更友好的outputs数据格式。此函数输出不会被缓存。
def m42_post_run_bigquant_run(outputs):
    return outputs

# Python 代码入口函数，input_1/2/3 对应三个输入端，data_1/2/3 对应三个输出端
def m1_run_bigquant_run(input_1, input_2, input_3):
    # 示例代码如下。在这里编写您的代码
    df = input_1.read_df()
    #df['date0'] = df['date'].apply(lambda x: x[0:11] + ' 00:00:00')
    df['date1'] = df['date'].apply(lambda x: datetime.datetime.strptime(x, '%Y-%m-%d'))
    df = df.drop(['date'], axis=1)
    df = df.rename(columns={'date1': 'date'})
    #df = pd.DataFrame({'data': [1, 2, 3]})
    data_1 = DataSource.write_df(df)
    data_2 = DataSource.write_pickle(df)
    return Outputs(data_1=data_1, data_2=None, data_3=None)

# 后处理函数，可选。输入是主函数的输出，可以在这里对数据做处理，或者返回更友好的outputs数据格式。此函数输出不会被缓存。
def m1_post_run_bigquant_run(outputs):
    return outputs

# Python 代码入口函数，input_1/2/3 对应三个输入端，data_1/2/3 对应三个输出端
def m10_run_bigquant_run(input_1, input_2, input_3):
    # 示例代码如下。在这里编写您的代码
    #df = pd.DataFrame({'data': [1, 2, 3]})
    df = input_1.read_df()
    df['instrument'] = 'BTC_USDT.HBI'
    data_1 = DataSource.write_df(df)
    #data_2 = DataSource.write_pickle(df)
    return Outputs(data_1=data_1, data_2=None, data_3=None)

# 后处理函数，可选。输入是主函数的输出，可以在这里对数据做处理，或者返回更友好的outputs数据格式。此函数输出不会被缓存。
def m10_post_run_bigquant_run(outputs):
    return outputs

# Python 代码入口函数，input_1/2/3 对应三个输入端，data_1/2/3 对应三个输出端
def m38_run_bigquant_run(input_1, input_2, input_3):
    # 示例代码如下。在这里编写您的代码
    #df = pd.DataFrame({'data': [1, 2, 3]})
    #data_1 = DataSource.write_df(df)
    from datetime import time
    df = input_1.read()
    # 直接根据回测数据的DataFrame的date来生成交易日历对象
    trading_date =df['date']  # 交易日历的日期
    trading_sections = [(time(00,00), time(23,59))]  # 交易日历的开、收盘时间
    # 生成交易日历
    trading_calendar = get_extend_calendar_with_tradingdays('BtcCalendar', tradingdays=trading_date, trading_sections=trading_sections)
    data_1 = DataSource.write_pickle(trading_calendar)
    return Outputs(data_1=data_1)

# 后处理函数，可选。输入是主函数的输出，可以在这里对数据做处理，或者返回更友好的outputs数据格式。此函数输出不会被缓存。
def m38_post_run_bigquant_run(outputs):
    return outputs

# 回测引擎：初始化函数，只执行一次
def m24_initialize_bigquant_run(context):
    # 加载预测数据
    context.predictions = context.options['data'].read_df()
    #context.last_residual = 0
    context.initial_max_daily_residual = 0.62
    context.initial_min_daily_residual = - 0.27
    #context.max_daily_residual = context.initial_max_daily_residual
    #context.min_daily_residual = context.initial_min_daily_residual
    context.predictions['zone'] = context.predictions['residual'].apply(lambda x: 'upvalue' if x > context.initial_max_daily_residual else 'reasonable' if x > context.initial_min_daily_residual else 'undervalue')
    context.trade_director = 'empty'
    #context.residual = []
    # 系统已经设置了默认的交易手续费和滑点，要修改手续费可使用如下函数
    #context.set_commission(PerOrder(buy_cost=0.0003, sell_cost=0.0013, min_cost=5))

# 回测引擎：每日数据处理函数，每天执行一次
def m24_handle_data_bigquant_run(context, data):
    # 按日期过滤得到今日的预测数据
    daily_prediction = context.predictions[
        context.predictions.date == data.current_dt.strftime('%Y-%m-%d')]
    daily_residual_s = daily_prediction['residual']
    for k, v in enumerate(daily_residual_s):
        daily_residual = v
    trading_days_s = daily_prediction['trading_days']
    for k, v in enumerate(trading_days_s):
        trading_days = v
    zone_s = daily_prediction['zone']
    for k, v in enumerate(zone_s):
        zone = v
    # 投资标的字符串格式
    instr_s = daily_prediction['instrument']
    for i, instrument in enumerate(instr_s):
        # 将标的转化为equity格式
        sid = context.symbol(instrument)
    price = data.current(sid, 'price')
    
    # 1. 资金分配
    cash_avg = context.portfolio.portfolio_value / trading_days
    cash_for_buy = min(context.portfolio.cash, cash_avg)
    amount_for_buy = cash_for_buy / price
    positions_amount = context.portfolio.positions[sid].amount
    amount_avg = cash_avg / price
    amount_for_sell = min(positions_amount, amount_avg)
    '''
    print('  date: ' + data.current_dt.strftime('%Y-%m-%d'))
    print('  zone: ' + str(zone))
    print('  context.trade_director: ' + str(context.trade_director))
    print('  cash_for_buy:' + str(cash_for_buy))
    print('  amount_for_buy:' + str(amount_for_buy))
    print('  data.can_trade(sid): ' + str(data.can_trade(sid)))
    print('  price: ' + str(price)) 
    print('  instrument: ' + instrument)
    print('  positions_amount: '+ str(positions_amount))
    '''
    # 2. 生成卖出订单：
   
    if (zone == 'upvalue' or (zone == 'reasonable' and context.trade_director == 'sell')) and positions_amount > 0 and data.can_trade(sid):
        '''
        print('    date: ' + data.current_dt.strftime('%Y-%m-%d'))
        print('    daily_residual: ' + str(daily_residual))
        print('    context.initial_max_daily_residual: ' + str(context.initial_max_daily_residual))
        print('    zone: ' + str(zone))
        print('    context.trade_director: ' + str(context.trade_director))
        print('    positions_amount: '+ str(positions_amount))
        print('    data.can_trade(sid): ' + str(data.can_trade(sid)))
        print('    price: ' + str(price)) 
        print('    instrument: ' + instrument)
        print('    sell signal')
        '''
        context.trade_director = 'sell'
        context.order(sid, - amount_for_sell)

        # 3. 生成买入订单：
    
    elif (zone == 'undervalue' or (zone == 'reasonable' and context.trade_director == 'buy')) and amount_for_buy > 100 and data.can_trade(sid):
        '''
        print('date: ' + data.current_dt.strftime('%Y-%m-%d'))
        print('zone: ' + str(zone))
        print('context.trade_director: ' + str(context.trade_director))
        print('cash_for_buy:' + str(cash_for_buy))
        print('amount_for_buy:' + str(amount_for_buy))
        print('data.can_trade(sid): ' + str(data.can_trade(sid)))
        print('price: ' + str(price)) 
        print('instrument: ' + instrument)
        print('positions_amount: '+ str(positions_amount))
        print('buy signal')
        '''
        context.trade_director = 'buy'
        context.order_value(sid, cash_for_buy)

# 回测引擎：准备数据，只执行一次
def m24_prepare_bigquant_run(context):
    #context.start_date = '2017-10-26'
    #context.end_date = '2018-07-10'
    #context.instruments = 'BTCUSD'
    pass

# 回测引擎：每个单位时间开始前调用一次，即每日开盘前调用一次。
def m24_before_trading_start_bigquant_run(context, data):
    pass


m8 = M.rename_columns1.v1(
    columns='Date@date|Value@market_cap',
    keep_old_columns=False
)

m15 = M.cached.v3(
    input_1=m8.data,
    run=m15_run_bigquant_run,
    post_run=m15_post_run_bigquant_run,
    input_ports='',
    params='{}',
    output_ports=''
)

m7 = M.cached.v3(
    input_1=m15.data_1,
    run=m7_run_bigquant_run,
    post_run=m7_post_run_bigquant_run,
    input_ports='',
    params='{}',
    output_ports=''
)

m12 = M.dropnan.v1(
    input_data=m7.data_1
)

m3 = M.sort.v4(
    input_ds=m12.data,
    sort_by='date',
    group_by='',
    keep_columns='date,market_cap',
    ascending=True
)

m17 = M.cached.v3(
    input_1=m3.sorted_data,
    run=m17_run_bigquant_run,
    post_run=m17_post_run_bigquant_run,
    input_ports='',
    params='{}',
    output_ports=''
)

m21 = M.cached.v3(
    input_1=m17.data_1,
    run=m21_run_bigquant_run,
    post_run=m21_post_run_bigquant_run,
    input_ports='',
    params='{}',
    output_ports=''
)

m20 = M.auto_labeler_on_datasource.v1(
    input_data=m21.data_1,
    label_expr="""# #号开始的表示注释
# 0. 每行一个，顺序执行，从第二个开始，可以使用label字段
# 1. 可用数据字段见 https://bigquant.com/docs/develop/datasource/deprecated/history_data.html
# 2. 可用操作符和函数见 `表达式引擎 <https://bigquant.com/docs/develop/bigexpr/usage.html>`_

# 计算收益：5日收盘价(作为卖出价格)除以明日开盘价(作为买入价格)
market_cap

# 极值处理：用1%和99%分位的值做clip
clip(label, all_quantile(label, 0.01), all_quantile(label, 0.99))

# 将分数映射到分类，这里使用20个分类
#all_wbins(label, 20)

# 过滤掉一字涨停的情况 (设置label为NaN，在后续处理和训练中会忽略NaN的label)
#where(shift(high, -1) == shift(low, -1), NaN, label)
""",
    drop_na_label=True,
    cast_label_int=False,
    date_col='date',
    instrument_col='instrument',
    user_functions={}
)

m4 = M.cached.v3(
    run=m4_run_bigquant_run,
    post_run=m4_post_run_bigquant_run,
    input_ports='',
    params='{}',
    output_ports=''
)

m25 = M.cached.v3(
    input_1=m4.data_1,
    run=m25_run_bigquant_run,
    post_run=m25_post_run_bigquant_run,
    input_ports='',
    params='{}',
    output_ports=''
)

m5 = M.cached.v3(
    input_1=m25.data_1,
    run=m5_run_bigquant_run,
    post_run=m5_post_run_bigquant_run,
    input_ports='',
    params='{}',
    output_ports=''
)

m11 = M.dropnan.v1(
    input_data=m5.data_1
)

m22 = M.cached.v3(
    input_1=m11.data,
    run=m22_run_bigquant_run,
    post_run=m22_post_run_bigquant_run,
    input_ports='',
    params='{}',
    output_ports=''
)

m14 = M.join.v3(
    data1=m20.data,
    data2=m22.data_1,
    on='date',
    how='inner',
    sort=False
)

m16 = M.filter.v3(
    input_data=m14.data,
    expr='date<\'2016-06-01\'',
    output_left_data=True
)

m6 = M.filter.v3(
    input_data=m14.data,
    expr='date<\'2015-06-01\'',
    output_left_data=True
)

m31 = M.filter.v3(
    input_data=m14.data,
    expr='date<\'2014-06-01\'',
    output_left_data=True
)

m44 = M.linear_regression_coef.v1(
    input_1=m14.data,
    factor='factor1'
)

m19 = M.input_features.v1(
    features="""
# #号开始的表示注释，注释需单独一行
# 多个特征，每行一个，可以包含基础特征和衍生特征，特征须为本平台特征
factor1
"""
)

m18 = M.linear_regression.v1(
    training_ds=m16.data,
    features=m19.data,
    predict_ds=m16.left_data,
    fit_intercept=True,
    normalize=False,
    key_cols='date,instrument',
    workers=1,
    other_train_parameters={}
)

m26 = M.metrics_regression.v1(
    predictions=m18.predictions,
    explained_variance_score=True,
    mean_absolute_error=True,
    mean_squared_error=True,
    mean_squared_log_error=True,
    median_absolute_error=True,
    r2_score=True
)

m29 = M.linear_regression.v1(
    training_ds=m6.data,
    features=m19.data,
    predict_ds=m6.left_data,
    fit_intercept=True,
    normalize=False,
    key_cols='date,instrument',
    workers=1,
    other_train_parameters={}
)

m30 = M.metrics_regression.v1(
    predictions=m29.predictions,
    explained_variance_score=True,
    mean_absolute_error=True,
    mean_squared_error=True,
    mean_squared_log_error=True,
    median_absolute_error=True,
    r2_score=True
)

m32 = M.linear_regression.v1(
    training_ds=m31.data,
    features=m19.data,
    predict_ds=m31.left_data,
    fit_intercept=True,
    normalize=False,
    key_cols='date,instrument',
    workers=1,
    other_train_parameters={}
)

m33 = M.metrics_regression.v1(
    predictions=m32.predictions,
    explained_variance_score=True,
    mean_absolute_error=True,
    mean_squared_error=True,
    mean_squared_log_error=True,
    median_absolute_error=True,
    r2_score=True
)

m34 = M.linear_regression.v1(
    training_ds=m14.data,
    features=m19.data,
    predict_ds=m14.data,
    fit_intercept=True,
    normalize=False,
    key_cols='date,instrument',
    workers=1,
    other_train_parameters={}
)

m35 = M.metrics_regression.v1(
    predictions=m34.predictions,
    explained_variance_score=True,
    mean_absolute_error=True,
    mean_squared_error=True,
    mean_squared_log_error=True,
    median_absolute_error=True,
    r2_score=True
)

m27 = M.cached.v3(
    input_1=m34.predictions,
    run=m27_run_bigquant_run,
    post_run=m27_post_run_bigquant_run,
    input_ports='',
    params='{}',
    output_ports=''
)

m36 = M.Tplot_COPY.v11(
    input_1=m27.data_1,
    y='residual,label',
    title='交易信号图',
    chart_type='line',
    chart_options={
    "chart": {"height": 1000},
    # 设置多个子图各自的y轴名称、子图位置等相关配置
    "yAxis": [
              {},
              {"title": {"text": "交易信号和市值对数"},"top": "10%","height": "90%","offset": 10}
             ],
    # 设置子图绘制的数据data、绘图类型type和对应的y轴配置yAxis(0表示yAxis配置列表的第一项，
    "series":[
              {},
              {"type":"line","yAxis":1}
              # 多个变量绘制在相同子图可设置相同的yAxis序号)
              #{"data":[m5.data.read()[["date"]],m5.data.read()[["volume"]]],"type":"column","yAxis":1},
             ]
}
)

m40 = M.trade_in_bulk_days.v1(
    input_1=m27.data_1,
    trading_days=12
)

m37 = M.Tplot_COPY.v11(
    input_1=m34.predictions,
    y='pred_label,label',
    title='预测图',
    chart_type='line',
    chart_options={
    "chart": {"height": 800},
    # 设置多个子图各自的y轴名称、子图位置等相关配置
    "yAxis": [
              {},
              {"title": {"text": "市值对数"},"top": "10%","height": "90%","offset": 10}
             ],
    # 设置子图绘制的数据data、绘图类型type和对应的y轴配置yAxis(0表示yAxis配置列表的第一项，
    "series":[
              {},
              {"type":"line","yAxis":0}
              # 多个变量绘制在相同子图可设置相同的yAxis序号)
              #{"data":[m5.data.read()[["date"]],m5.data.read()[["volume"]]],"type":"column","yAxis":1},
             ]
}
)

m23 = M.cached.v3(
    run=m23_run_bigquant_run,
    post_run=m23_post_run_bigquant_run,
    input_ports='',
    params='{\'string\':\'BTC_USDT.HBI\',\'start_date\':\'2011-09-13\', \'end_date\':\'2020-04-25\', \'market\':\'DCC\'}',
    output_ports='data_1'
)

m9 = M.rename_columns1.v1(
    columns='Date@date|Open@open|High@high|Low@low|Close@close|Volume (BTC)@volume|Weighted Price@vwap_11',
    keep_old_columns=False
)

m42 = M.cached.v3(
    input_1=m9.data,
    run=m42_run_bigquant_run,
    post_run=m42_post_run_bigquant_run,
    input_ports='',
    params='{}',
    output_ports=''
)

m39 = M.fill_nan.v8(
    input_1=m42.data_1,
    columns_input=['open','high','low','close','volume','vwap_11'],
    group_key=[],
    method='向下向上填充'
)

m1 = M.cached.v3(
    input_1=m39.data,
    run=m1_run_bigquant_run,
    post_run=m1_post_run_bigquant_run,
    input_ports='',
    params='{}',
    output_ports=''
)

m10 = M.cached.v3(
    input_1=m1.data_1,
    run=m10_run_bigquant_run,
    post_run=m10_post_run_bigquant_run,
    input_ports='',
    params='{}',
    output_ports=''
)

m13 = M.sort.v4(
    input_ds=m10.data_1,
    sort_by='date',
    group_by='',
    keep_columns='',
    ascending=True
)

m38 = M.cached.v3(
    input_1=m13.sorted_data,
    run=m38_run_bigquant_run,
    post_run=m38_post_run_bigquant_run,
    input_ports='',
    params='{}',
    output_ports=''
)

m24 = M.trade.v4(
    instruments=m23.data_1,
    options_data=m40.data_1,
    history_ds=m13.sorted_data,
    benchmark_ds=m13.sorted_data,
    trading_calendar=m38.data_1,
    start_date='',
    end_date='',
    initialize=m24_initialize_bigquant_run,
    handle_data=m24_handle_data_bigquant_run,
    prepare=m24_prepare_bigquant_run,
    before_trading_start=m24_before_trading_start_bigquant_run,
    volume_limit=0.1,
    order_price_field_buy='open',
    order_price_field_sell='close',
    capital_base=6000,
    auto_cancel_non_tradable_orders=True,
    data_frequency='daily',
    price_type='真实价格',
    product_type='期货',
    plot_charts=True,
    backtest_only=False,
    benchmark='BTC_USDT.HBI'
)
# Out:
# [2020-04-30 17:43:21.318208] INFO: moduleinvoker: btc_factor1.v2 开始运行..
# [2020-04-30 17:43:21.323925] INFO: moduleinvoker: 命中缓存
# [2020-04-30 17:43:21.325539] INFO: moduleinvoker: btc_factor1.v2 运行完成[0.007355s].
# [2020-04-30 17:43:21.330184] INFO: moduleinvoker: cached.v3 开始运行..
# [2020-04-30 17:43:21.334856] INFO: moduleinvoker: 命中缓存
# [2020-04-30 17:43:21.336294] INFO: moduleinvoker: cached.v3 运行完成[0.006112s].
# [2020-04-30 17:43:21.340346] INFO: moduleinvoker: cached.v3 开始运行..
# [2020-04-30 17:43:21.345125] INFO: moduleinvoker: 命中缓存
# [2020-04-30 17:43:21.346352] INFO: moduleinvoker: cached.v3 运行完成[0.006008s].
# [2020-04-30 17:43:21.350062] INFO: moduleinvoker: cached.v3 开始运行..
# [2020-04-30 17:43:21.355101] INFO: moduleinvoker: 命中缓存
# [2020-04-30 17:43:21.356274] INFO: moduleinvoker: cached.v3 运行完成[0.006214s].
# [2020-04-30 17:43:21.358634] INFO: moduleinvoker: dropnan.v1 开始运行..
# [2020-04-30 17:43:21.364207] INFO: moduleinvoker: 命中缓存
# ...

# %%
m24.pyfolio_full_tear_sheet()
# Out:
# Entire data start date: 2011-09-13
# Entire data end date: 2020-04-25
#
#
# Backtest Months: 149
# Performance statistics   Backtest
# cum_returns_final         9109.60
# annual_return                1.07
# annual_volatility            0.45
# sharpe_ratio                 1.84
# calmar_ratio                 2.54
# stability_of_timeseries      0.92
# max_drawdown                -0.42
# omega_ratio                  1.63
# sortino_ratio                2.94
# skew                         0.24
# kurtosis                    16.96
# tail_ratio                   1.59
# common_sense_ratio           3.29
# information_ratio           -0.01
# alpha                        0.82
# beta                         0.00
# Worst Drawdown Periods net drawdown in %  peak date valley date recovery date  \
# 0                                  42.28 2013-11-18  2015-01-14    2015-07-12
# 1                                  38.53 2012-08-16  2012-08-19    2012-12-06
# ...

# %%
m24.factor_profit_analyze()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# KeyError: datetime.date(2011, 9, 17)
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# KeyError: datetime.date(2011, 9, 17)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# KeyError: 1316217600000000000
#
# ...

# %%
m24.risk_analyze()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# KeyError: datetime.date(2011, 9, 17)
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# KeyError: datetime.date(2011, 9, 17)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# KeyError: 1316217600000000000
#
# ...
