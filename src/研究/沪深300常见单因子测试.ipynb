# %%
# 本代码由可视化策略环境自动生成 2022年4月27日 19:55
# 本代码单元只能在可视化模式下编辑。您也可以拷贝代码，粘贴到新建的代码单元或者策略，然后修改。


m1 = M.input_features.v1(
    features="""# ----------------------------  量价因子  ---------------------------- #
# last_day_vol = volume_0/volume_1
# (high_0-low_0+high_1-low_1+high_2-low_2+high_3-low_3+high_4-low_4)/5,
# daily_return_1
# return_10
# return_20
# avg_amount_5 = avg_amount_5
# avg_amount_20

#换手率因子
# avg_turn_5

# ------------------------------------------------------------------- #

# --------------------------  基本面因子  ---------------------------- #
#估值因子
pe_ttm_0
# pb_lf_0

#资金流
# mf_net_amount_main_0,
# rank_avg_mf_net_amount_5,
# rank_return_10, 
# swing_volatility_10_0/swing_volatility_60_0
    
# 打扮因子
# price_limit_status_0 * turn_0 + volatility_60_0
# price_limit_status_1*turn_0 + volatility_60_0
# price_limit_status_2*turn_0 + volatility_60_0
# price_limit_status_3*turn_0 + volatility_60_0
# price_limit_status_4*turn_0 + volatility_60_0
# price_limit_status_5*turn_0 + volatility_60_0

# finhack factor
# std(avg_turn_0,10)
# avg_turn_5
# std(avg_turn_0,30)
# avg_turn_10
# std(avg_turn_0,5)
# rank_swing_volatility_60_0
# std(avg_turn_0,60)
# (min(product(rank(rank(log(sum(ts_min(rank(rank((-1*rank(delta((close_1 - 1),5))))),2),1)))),1),5) +ts_rank(delay((-1*return_1),6),5))
# rank_swing_volatility_120_0
# swing_volatility_60_0
# swing_volatility_120_0

# beta_szzs_10_0/beta_szzs_5_0    # 大盘5日和10日涨幅对比
# rank_beta_industry1_5_0         # 行业5日内排名
# ta_wma_5_0                      # 5日加权均线
# close_1/west_eps_ftm_0          # 昨日收盘价对比eps一致性预期，即未来PE，存在覆盖率低于50%的情况
# pe_lyr_0/pe_ttm_0               # 静态PE/PE_TTM
# pe_ttm_0/(close_1/west_eps_ftm_0)  # PE_TTM/动态PE
# pe_lyr_0/(close_1/west_eps_ftm_0)  # 静态PE/动态PE，存在覆盖率低于20%的情况
# company_found_date_0               # 公司建立时间
# fs_roe_ttm_0                       # ROE_TTM
# fs_eps_yoy_0                       # eps增速
# market_cap_0                       # 市值
# avg_mf_net_amount_20/avg_mf_net_amount_5  # 5日和20日资金
# volume_20/volume_5                 # 5日和20日量比"""
)

m5 = M.factorlens.v2(
    features=m1.data,
    title='因子分析: {factor_name}',
    start_date='2020-01-01',
    end_date='2022-01-01',
    rebalance_period=22,
    delay_rebalance_days=0,
    rebalance_price='open_0',
    stock_pool='沪深300',
    quantile_count=10,
    commission_rate=0,
    returns_calculation_method='累乘',
    benchmark='无',
    drop_new_stocks=60,
    drop_price_limit_stocks=True,
    drop_st_stocks=True,
    drop_suspended_stocks=True,
    cutoutliers=True,
    normalization=True,
    neutralization=['行业', '市值'],
    metrics=['因子表现概览', '因子分布', '因子行业分布', '因子市值分布', 'IC分析', '买入信号重合分析', '因子估值分析', '因子拥挤度分析', '因子值最大/最小股票', '表达式因子值', '多因子相关性分析'],
    factor_coverage=0.2,
    user_data_merge='left'
)

m3 = M.factorlens_preservation.v2(
    factors_info=m5.save_data,
    factor_fields=# 定义因子名称
# {
#     "列名": {'name': "因子名", 'desc': "因子描述"},
#     "列名": {'name': "因子名", 'desc': "因子描述"},
#     ... 
# }
{}
,
    table=''
)
# Out:
# [2022-04-27 19:53:06.274307] INFO: moduleinvoker: input_features.v1 开始运行..
# [2022-04-27 19:53:06.470853] INFO: moduleinvoker: input_features.v1 运行完成[0.196551s].
# [2022-04-27 19:53:06.478575] INFO: moduleinvoker: factorlens.v2 开始运行..
# [2022-04-27 19:53:06.522427] INFO: 因子分析: batch_process start
# [2022-04-27 19:53:06.525553] INFO: 因子分析: load_instruments 2020-01-01, 2022-01-01
# [2022-04-27 19:53:07.436304] INFO: 因子分析: load_instruments, 4723 rows.
# [2022-04-27 19:53:07.437953] INFO: 因子分析: load_benchmark_data 2020-01-01, 2022-01-01
# [2022-04-27 19:53:07.565970] INFO: 因子分析: load_benchmark_data, 1458 rows.
# [2022-04-27 19:53:07.567953] INFO: 因子分析: StockPool.before_load_general_feature_data
# [2022-04-27 19:53:07.569527] INFO: 因子分析: UserDataMerge.before_load_general_feature_data
# [2022-04-27 19:53:07.571057] INFO: 因子分析: DropSTStocks.before_load_general_feature_data
# [2022-04-27 19:53:07.572805] INFO: 因子分析: DropNewStocks.before_load_general_feature_data
# ...
